# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
from urllib.error import URLError, HTTPError

# %%
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'}
headers2 = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'}

# %%
url = 'https://howlongtobeat.com/game?id=3521'
try:
    req = Request(url, headers=headers)
    response = urlopen(req)
    html = response.read()
    html
except HTTPError as e:
    print(e.status, e.reason)
except URLError as e:
    print(e.reason)
# Out:
# 404 Not Found

# %%
type(html)
# Out:
# bytes

# %%
html = html.decode('utf-8')

# %%
html = " ".join(html.split()).replace('> <','><')

# %%
type(html)
# Out:
# str

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/css/main.css?release=v1.0.59" rel="stylesheet"/>
#   <link href="/css/light.css?release=v1.0.59" rel="stylesheet"/>
#   <link href="/css/desktop.css?release=v1.0.59" media="screen and (min-width: 769px)" rel="stylesheet"/>
#   <link href="/css/mobile.css?release=v1.0.59" media="screen and (max-width: 768px)" rel="stylesheet"/>
#   <script src="/sw.js" type="text/javascript">
#   </script>
#   <script src="/js/site.js?release=v1.0.59" type="text/javascript">
#   </script>
#   <script src="/js/bobble.js?release=v1.0.59" type="text/javascript">
#   </script>
#   <title>
#    How long is Final Fantasy VII? | HowLongToBeat
#   </title>
# ...

# %%
soup.html.head.title
# Out:
# <title>How long is Final Fantasy VII? | HowLongToBeat</title>

# %%
a = soup.find_all("div", {"class": "game_times"})

# %%
soup.h5
# Out:
# <h5 class="left">Platform</h5>

# %%
type(a)
# Out:
# bs4.element.ResultSet

# %%
soup.getText()
# Out:
# 'How long is Final Fantasy VII? | HowLongToBeatForumStatsSubmitLoginJoinGames ListUser ListPlatformAllEmulatedNintendo 3DSNintendo SwitchPCPlayStation 3PlayStation 4PlayStation 5PlayStation NowWii UXbox 360Xbox OneXbox Series X/S3DOAcorn ArchimedesAmigaAmiga CD32Amstrad CPCAndroidApple IIArcadeAtari 8-bit FamilyAtari 2600Atari 5200Atari 7800Atari JaguarAtari Jaguar CDAtari LynxAtari STBBC MicroBrowserColecoVisionCommodore 64Commodore PETCommodore VIC-20DreamcastEmulatedFM TownsGame & WatchGame BoyGame Boy AdvanceGame Boy ColorGear VRGizmondoGoogle StadiaIntellivisionInteractive MovieiOSLinuxMacMobileMSXN-GageNEC PC-88NEC PC-98NEC PC-FXNeo GeoNeo Geo CDNeo Geo PocketNESNintendo 3DSNintendo 64Nintendo DSNintendo GameCubeNintendo SwitchOculus GoOculus QuestOdysseyOdyssey 2OnLiveOuyaPCPC VRPhilips CD-iPlayStationPlayStation 2PlayStation 3PlayStation 4PlayStation 5PlayStation MobilePlayStation NowPlayStation PortablePlayStation VitaPlayStation VRPlug & PlaySega 32XSega CDSega Game GearSeg
# ...

# %%
soup.ul
# Out:
# <ul class="site"><li><a class="text_primary" href="forum">Forum</a></li><li><a class="text_primary" href="stats">Stats</a></li><li><a class="text_primary" href="submit">Submit</a></li></ul>

# %%
soup.div["class"]
# Out:
# ['container']

# %%
soup.find(class_="game_times").getText()
# Out:
# 'Main Story36½ Hours Main + Extras51 Hours Completionist83½ Hours All Styles49½ Hours '

# %%
soup.find(class_="game_times").find_all('h5')
# Out:
# [<h5>Main Story</h5>,
#  <h5>Main + Extras</h5>,
#  <h5>Completionist</h5>,
#  <h5>All Styles</h5>]

# %%
soup.find(class_="game_times").find_all('li')[0].getText().replace(soup.find(class_="game_times").find_all('h5')[0].getText(),'')
# Out:
# '36½ Hours '

# %%
soup.find(class_="game_times").find_all('h5')[0].getText()
# Out:
# 'Main Story'

# %%
soup.find(class_="game_times").find_all('li')
# Out:
# [<li class="short time_100"><h5>Main Story</h5><div>36½ Hours </div></li>,
#  <li class="short time_100"><h5>Main + Extras</h5><div>51 Hours </div></li>,
#  <li class="short time_100"><h5>Completionist</h5><div>83½ Hours </div></li>,
#  <li class="short time_100"><h5>All Styles</h5><div>49½ Hours </div></li>]

# %%
soup.find_all(class_="profile_info")
# Out:
# [<div class="profile_info large"> Long recognized as role-playing games par excellence, the Final Fantasy series gets a technological makeover in this installment (and series debut on the PlayStation). Shedding the two-dimensional graphics and limited sound capabilities of its predecessors, Final Fantasy VII features lush 3-D graphics, beautifully animated "movie" sequences, and so<a id="profile_summary_more" onclick="document.getElementById('profile_summary_more').style.display = 'none';document.getElementById('profile_summary_rest').style.display = 'inline';">...Read More</a><span id="profile_summary_rest" style="display:none;">undtrack-quality music. Coupled with the game's intricate storyline, endearing characters, and immense yet highly imaginative world, these new advancements make for a quite an engrossing experience.</span></div>,
#  <div class="profile_info large"><strong> Platforms: </strong><br/> Mobile, Nintendo Switch, PC, PlayStation, PlayStation 4, Xbox One </div>,
# ...

# %%
soup.find_all(class_="profile_info")[0]
# Out:
# <div class="profile_info large"> Long recognized as role-playing games par excellence, the Final Fantasy series gets a technological makeover in this installment (and series debut on the PlayStation). Shedding the two-dimensional graphics and limited sound capabilities of its predecessors, Final Fantasy VII features lush 3-D graphics, beautifully animated "movie" sequences, and so<a id="profile_summary_more" onclick="document.getElementById('profile_summary_more').style.display = 'none';document.getElementById('profile_summary_rest').style.display = 'inline';">...Read More</a><span id="profile_summary_rest" style="display:none;">undtrack-quality music. Coupled with the game's intricate storyline, endearing characters, and immense yet highly imaginative world, these new advancements make for a quite an engrossing experience.</span></div>

# %%
soup.find_all(class_="profile_info")[1]
# Out:
# <div class="profile_info large"><strong> Platforms: </strong><br/> Mobile, Nintendo Switch, PC, PlayStation, PlayStation 4, Xbox One </div>

# %%
soup.find_all(class_="profile_info")[2]
# Out:
# <div class="profile_info medium"><strong> Genre: </strong><br/> Role-Playing </div>

# %%
soup.find_all("strong")[0].getText()
# Out:
# ' Platforms: '

# %%
soup.find_all(class_="profile_info")[1].getText()
# Out:
# ' Platforms:  Mobile, Nintendo Switch, PC, PlayStation, PlayStation 4, Xbox One '

# %%
a = soup.find_all(class_="profile_info")[1].getText().replace(soup.find_all("strong")[0].getText(),"")

# %%
a
# Out:
# ' Mobile, Nintendo Switch, PC, PlayStation, PlayStation 4, Xbox One '

# %%
soup.find_all(class_="profile_header shadow_text")[0].getText()
# Out:
# ' Final Fantasy VII '

# %%
soup.find_all(class_="profile_header shadow_text")[0].getText()
# Out:
# ' Final Fantasy VII '

# %%
Main_Story
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-dddb2fce74ee> in <module>
# ----> 1 Main_Story
#
# NameError: name 'Main_Story' is not defined

# %%
for j in soup.find_all(class_="profile_info"):
    
    print(j.getText())
# Out:
#  Long recognized as role-playing games par excellence, the Final Fantasy series gets a technological makeover in this installment (and series debut on the PlayStation). Shedding the two-dimensional graphics and limited sound capabilities of its predecessors, Final Fantasy VII features lush 3-D graphics, beautifully animated "movie" sequences, and so...Read Moreundtrack-quality music. Coupled with the game's intricate storyline, endearing characters, and immense yet highly imaginative world, these new advancements make for a quite an engrossing experience.
#  Platforms:  Mobile, Nintendo Switch, PC, PlayStation, PlayStation 4, Xbox One
#  Genre:  Role-Playing
#  Developer:  Square
#  Publisher:  Square
# NA:September 07, 1997
# EU:November 17, 1997
# JP:January 31, 1997
# Updated:2.5 Hours Ago
#  Alias:  Final Fantasy 7

# %%
.count('Genre:')
